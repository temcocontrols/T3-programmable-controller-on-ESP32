# %% [markdown]
# <a href="https://colab.research.google.com/github/temcocontrols/T3-programmable-controller-on-ESP32/blob/Maurice/Tstat11_Snippets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
