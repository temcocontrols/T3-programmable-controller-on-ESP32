# %%
# name: Tstat11_Main_UI
# description: Interactive Home Screen for the Tstat11.

from IPython.display import display, HTML

html_code = """
<div id='device-bezel' style='width:480px; height:320px; background:black; border:12px solid #333; border-radius:15px; position:relative; overflow:hidden; font-family:sans-serif;'>
    <div style='position:absolute; top:12px; left:15px; font-size:28px; cursor:pointer; z-index:10;' onclick='alert("Settings Menu")'>⚙️</div>
    <div style='position:absolute; top:12px; right:15px; font-size:28px; cursor:pointer; z-index:10;' onclick='alert("Schedule Menu")'>📅</div>
    <div style='position:absolute; bottom:12px; left:15px; font-size:28px; cursor:pointer; z-index:10;' onclick='alert("Mode Selection")'>❄️</div>
    <div style='position:absolute; bottom:12px; right:15px; font-size:28px; cursor:pointer; z-index:10;' onclick='alert("Fan Control")'>🌀</div>

    <div style='text-align:center; margin-top:100px;'>
        <div style='font-size:72px; font-weight:bold; color:white; letter-spacing:-2px;'>72.5°F</div>
        <div style='color:#00A4FF; font-size:16px; font-weight:bold; margin-top:5px; text-transform:uppercase;'>Cooling • Auto</div>
    </div>

    <div style='position:absolute; bottom:15px; width:100%; text-align:center; color:#555; font-size:12px;'>
        TEMCO CONTROLS • TSTAT11
    </div>
</div>
"""
display(HTML(html_code))
